# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Matches File
matches_file = "/Users/danie/Desktop/final project/FinalProject/DanielGonzalez/matches_2004to2021.csv"

# %%
# Dataframe
matches_file_df = pd.read_csv(matches_file)
matches_file_df
# Out:
# C:\Users\danie\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (50,102,123,125,129,131,133,135,137,139,141,143,145,147,149,157,158,160,161,163,165,167,169,171,173,184,186,187,205,206) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           id                  home                    away               date  \
# 0     143898             DC United    San Jose Earthquakes  Saturday, April 3
# 1     143902             LA Galaxy  New England Revolution  Saturday, April 3
# 2     143899      Columbus Crew SC      New York Red Bulls  Saturday, April 3
# 3     143901             FC Dallas         Colorado Rapids  Saturday, April 3
# 4     143900  Sporting Kansas City         Chicago Fire FC  Saturday, April 3
# ...      ...                   ...                     ...                ...
# ...

# %%
matches_file_df.drop(columns=['time (utc)'], inplace=True)

# %%
matches_file_df
# Out:
#           id                  home                    away               date  \
# 0     143898             DC United    San Jose Earthquakes  Saturday, April 3
# 1     143902             LA Galaxy  New England Revolution  Saturday, April 3
# 2     143899      Columbus Crew SC      New York Red Bulls  Saturday, April 3
# 3     143901             FC Dallas         Colorado Rapids  Saturday, April 3
# 4     143900  Sporting Kansas City         Chicago Fire FC  Saturday, April 3
# ...      ...                   ...                     ...                ...
# 5226  597845   Vancouver Whitecaps          Real Salt Lake  Wednesday, July 7
# 5227  597846             LA Galaxy               FC Dallas  Wednesday, July 7
# 5228  597848          Nashville SC       Atlanta United FC   Thursday, July 8
# 5229  597847    New York Red Bulls      Philadelphia Union   Thursday, July 8
# 5230  597840         FC Cincinnati           Columbus Crew     Friday, July 9
#
# ...

# %%
matches_file_df.dtypes
# Out:
# id                        int64
# home                     object
# away                     object
# date                     object
# year                      int64
#                          ...
# away_bench_14_num       float64
# away_bench_14            object
# away_bench_14_minute     object
# home_formation           object
# away_formation           object
# Length: 209, dtype: object

# %%
matches_file_df.columns.all
# Out:
# <bound method Index.all of Index(['id', 'home', 'away', 'date', 'year', 'time (utc)', 'attendance',
#        'venue', 'league', 'part_of_competition',
#        ...
#        'away_offsides', 'home_wonCorners', 'away_wonCorners', 'home_saves',
#        'away_saves', 'away_bench_14_num', 'away_bench_14',
#        'away_bench_14_minute', 'home_formation', 'away_formation'],
#       dtype='object', length=209)>

# %%
matches_file_df.shape
# Out:
# (5231, 209)

# %%
matches_file_df = pd.to_frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-e65fc83399aa> in <module>
# ----> 1 matches_file_df = pd.to_frame()
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'to_frame'

# %%
pd.options.display.max_columns=None

# %%
matches_file_df
# Out:
#           id                  home                    away               date  \
# 0     143898             DC United    San Jose Earthquakes  Saturday, April 3
# 1     143902             LA Galaxy  New England Revolution  Saturday, April 3
# 2     143899      Columbus Crew SC      New York Red Bulls  Saturday, April 3
# 3     143901             FC Dallas         Colorado Rapids  Saturday, April 3
# 4     143900  Sporting Kansas City         Chicago Fire FC  Saturday, April 3
# ...      ...                   ...                     ...                ...
# 5226  597845   Vancouver Whitecaps          Real Salt Lake  Wednesday, July 7
# 5227  597846             LA Galaxy               FC Dallas  Wednesday, July 7
# 5228  597848          Nashville SC       Atlanta United FC   Thursday, July 8
# 5229  597847    New York Red Bulls      Philadelphia Union   Thursday, July 8
# 5230  597840         FC Cincinnati           Columbus Crew     Friday, July 9
#
# ...

# %%
matches_file_df.drop(columns=['away_bench_14_num', 'away_bench_14', 'away_bench_14_minute', 'away_bench_13_minute', 'away_bench_13', 'away_bench_13_num', 'away_starting_22', 'away_starting_22_num', 'away_bench_12_num', 'away_bench_12_minute', 'away_bench_12', 'away_bench_11', 'away_bench_11_num', 'away_bench_11_minute',  ], inplace=True)

# %%
matches_file_df
# Out:
#           id                  home                    away               date  \
# 0     143898             DC United    San Jose Earthquakes  Saturday, April 3
# 1     143902             LA Galaxy  New England Revolution  Saturday, April 3
# 2     143899      Columbus Crew SC      New York Red Bulls  Saturday, April 3
# 3     143901             FC Dallas         Colorado Rapids  Saturday, April 3
# 4     143900  Sporting Kansas City         Chicago Fire FC  Saturday, April 3
# ...      ...                   ...                     ...                ...
# 5226  597845   Vancouver Whitecaps          Real Salt Lake  Wednesday, July 7
# 5227  597846             LA Galaxy               FC Dallas  Wednesday, July 7
# 5228  597848          Nashville SC       Atlanta United FC   Thursday, July 8
# 5229  597847    New York Red Bulls      Philadelphia Union   Thursday, July 8
# 5230  597840         FC Cincinnati           Columbus Crew     Friday, July 9
#
# ...

# %%
selection = matches_file_df[['id','home','away', 'date', 'year', 'attendance', 'venue', 'league', 'part_of_competition',	'game_status', 'shootout', 'home_score', 'away_score', 'home_possessionPct', 'away_possessionPct', 'home_shotsSummary',	'away_shotsSummary', 'home_foulsCommitted', 'away_foulsCommitted', 'home_yellowCards', 'away_yellowCards', 'home_redCards', 'away_redCards', 'home_offsides', 'away_offsides', 'home_wonCorners', 'away_wonCorners', 'home_saves', 'away_saves', 'home_formation', 'away_formation']]
print(selection)
# Out:
#           id                  home                    away               date  \
# 0     143898             DC United    San Jose Earthquakes  Saturday, April 3
# 1     143902             LA Galaxy  New England Revolution  Saturday, April 3
# 2     143899      Columbus Crew SC      New York Red Bulls  Saturday, April 3
# 3     143901             FC Dallas         Colorado Rapids  Saturday, April 3
# 4     143900  Sporting Kansas City         Chicago Fire FC  Saturday, April 3
# ...      ...                   ...                     ...                ...
# 5226  597845   Vancouver Whitecaps          Real Salt Lake  Wednesday, July 7
# 5227  597846             LA Galaxy               FC Dallas  Wednesday, July 7
# 5228  597848          Nashville SC       Atlanta United FC   Thursday, July 8
# 5229  597847    New York Red Bulls      Philadelphia Union   Thursday, July 8
# 5230  597840         FC Cincinnati           Columbus Crew     Friday, July 9
#
# ...
