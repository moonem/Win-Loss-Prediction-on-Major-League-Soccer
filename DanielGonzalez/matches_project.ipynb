# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Matches File
matches_file = "/Users/danie/Desktop/matches.csv"

# %%
#/Users/danie/Desktop/matches.csv

# %%
# Dataframe
matches_file_df = pd.read_csv(matches_file)
matches_file_df
# Out:
# C:\Users\danie\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (11,14,50,102,123,125,129,131,133,135,137,139,141,143,145,147,149,157,158,160,161,163,165,167,169,171,173,184,186,187,205,206) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#             id                 home                away               date  \
# 0          NaN          New England            San Jose          7/31/1996
# 1          NaN               Dallas            Colorado          6/15/1996
# 2          NaN             Colorado         D.C. United          8/29/1996
# 3          NaN            LA Galaxy         New England           8/8/1996
# 4          NaN          New England         D.C. United          7/20/1996
# ...        ...                  ...                 ...                ...
# 6693  597845.0  Vancouver Whitecaps      Real Salt Lake  Wednesday, July 7
# 6694  597846.0            LA Galaxy           FC Dallas  Wednesday, July 7
# 6695  597848.0         Nashville SC   Atlanta United FC   Thursday, July 8
# 6696  597847.0   New York Red Bulls  Philadelphia Union   Thursday, July 8
# 6697  597840.0        FC Cincinnati       Columbus Crew     Friday, July 9
#
#       year time (utc) attendance                                     venue  \
# 0     1996        NaN     12,871                           Foxboro Stadium
# 1     1996        NaN      9,704                               Cotton Bowl
# 2     1996        NaN      6,368                         Mile High Stadium
# 3     1996        NaN     10,251                                 Rose Bowl
# 4     1996        NaN     18,347                           Foxboro Stadium
# ...    ...        ...        ...                                       ...
# 6693  2021       2:00     12,009              Rio Tinto Stadium, Sandy, UT
# 6694  2021       2:30     16,453        Dignity Health Sports Park, Carson
# 6695  2021       0:30     22,913  Nissan Stadium, Nashville, Nashville, TN
# 6696  2021       0:30     10,013                  Red Bull Arena, Harrison
# 6697  2021      23:30     25,701               TQL Stadium, Cincinnati, OH
#
#                         league part_of_competition  ... away_offsides  \
# 0                     1996 MLS      Regular Season  ...           NaN
# 1                     1996 MLS      Regular Season  ...           NaN
# 2                     1996 MLS      Regular Season  ...           NaN
# 3                     1996 MLS      Regular Season  ...           NaN
# 4                     1996 MLS      Regular Season  ...           NaN
# ...                        ...                 ...  ...           ...
# 6693  2021 Major League Soccer      Regular Season  ...           0.0
# 6694  2021 Major League Soccer      Regular Season  ...           3.0
# 6695  2021 Major League Soccer      Regular Season  ...           1.0
# 6696  2021 Major League Soccer      Regular Season  ...           4.0
# 6697  2021 Major League Soccer      Regular Season  ...           0.0
#
#      home_wonCorners  away_wonCorners  home_saves away_saves  \
# 0                NaN              NaN         NaN        NaN
# 1                NaN              NaN         NaN        NaN
# 2                NaN              NaN         NaN        NaN
# 3                NaN              NaN         NaN        NaN
# 4                NaN              NaN         NaN        NaN
# ...              ...              ...         ...        ...
# 6693             5.0              4.0         4.0        2.0
# 6694             2.0              2.0         3.0        2.0
# 6695             6.0              3.0         0.0        6.0
# 6696             5.0              5.0         5.0        2.0
# 6697             2.0              1.0         0.0        1.0
#
#      away_bench_14_num away_bench_14 away_bench_14_minute home_formation  \
# 0                  NaN           NaN                  NaN            NaN
# 1                  NaN           NaN                  NaN            NaN
# 2                  NaN           NaN                  NaN            NaN
# 3                  NaN           NaN                  NaN            NaN
# 4                  NaN           NaN                  NaN            NaN
# ...                ...           ...                  ...            ...
# 6693               NaN           NaN                  NaN       4/3/2003
# 6694               NaN           NaN                  NaN        4-2-3-1
# 6695               NaN           NaN                  NaN        3-4-1-2
# 6696               NaN           NaN                  NaN       4/4/2002
# 6697               NaN           NaN                  NaN        4-2-3-1
#
#       away_formation
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 6693         4-2-3-1
# 6694         4-2-3-1
# 6695       4-1-2-1-2
# 6696         4-3-1-2
# 6697         4-2-3-1
#
# [6698 rows x 209 columns]

# %%
matches_file_df.drop(columns=['time (utc)','venue','game_status'], inplace=True)

# %%
matches_file_df
# Out:
#             id                 home                away               date  \
# 0          NaN          New England            San Jose          7/31/1996
# 1          NaN               Dallas            Colorado          6/15/1996
# 2          NaN             Colorado         D.C. United          8/29/1996
# 3          NaN            LA Galaxy         New England           8/8/1996
# 4          NaN          New England         D.C. United          7/20/1996
# ...        ...                  ...                 ...                ...
# 6693  597845.0  Vancouver Whitecaps      Real Salt Lake  Wednesday, July 7
# 6694  597846.0            LA Galaxy           FC Dallas  Wednesday, July 7
# 6695  597848.0         Nashville SC   Atlanta United FC   Thursday, July 8
# 6696  597847.0   New York Red Bulls  Philadelphia Union   Thursday, July 8
# 6697  597840.0        FC Cincinnati       Columbus Crew     Friday, July 9
#
#       year attendance                    league part_of_competition shootout  \
# 0     1996     12,871                  1996 MLS      Regular Season      NaN
# 1     1996      9,704                  1996 MLS      Regular Season    2-Apr
# 2     1996      6,368                  1996 MLS      Regular Season      NaN
# 3     1996     10,251                  1996 MLS      Regular Season      NaN
# 4     1996     18,347                  1996 MLS      Regular Season      NaN
# ...    ...        ...                       ...                 ...      ...
# 6693  2021     12,009  2021 Major League Soccer      Regular Season    False
# 6694  2021     16,453  2021 Major League Soccer      Regular Season    False
# 6695  2021     22,913  2021 Major League Soccer      Regular Season    False
# 6696  2021     10,013  2021 Major League Soccer      Regular Season    False
# 6697  2021     25,701  2021 Major League Soccer      Regular Season    False
#
#       home_score  ...  away_offsides home_wonCorners away_wonCorners  \
# 0              2  ...            NaN             NaN             NaN
# 1              1  ...            NaN             NaN             NaN
# 2              1  ...            NaN             NaN             NaN
# 3              1  ...            NaN             NaN             NaN
# 4              2  ...            NaN             NaN             NaN
# ...          ...  ...            ...             ...             ...
# 6693           0  ...            0.0             5.0             4.0
# 6694           3  ...            3.0             2.0             2.0
# 6695           2  ...            1.0             6.0             3.0
# 6696           1  ...            4.0             5.0             5.0
# 6697           2  ...            0.0             2.0             1.0
#
#      home_saves away_saves away_bench_14_num  away_bench_14  \
# 0           NaN        NaN               NaN            NaN
# 1           NaN        NaN               NaN            NaN
# 2           NaN        NaN               NaN            NaN
# 3           NaN        NaN               NaN            NaN
# 4           NaN        NaN               NaN            NaN
# ...         ...        ...               ...            ...
# 6693        4.0        2.0               NaN            NaN
# 6694        3.0        2.0               NaN            NaN
# 6695        0.0        6.0               NaN            NaN
# 6696        5.0        2.0               NaN            NaN
# 6697        0.0        1.0               NaN            NaN
#
#      away_bench_14_minute  home_formation away_formation
# 0                     NaN             NaN            NaN
# 1                     NaN             NaN            NaN
# 2                     NaN             NaN            NaN
# 3                     NaN             NaN            NaN
# 4                     NaN             NaN            NaN
# ...                   ...             ...            ...
# 6693                  NaN        4/3/2003        4-2-3-1
# 6694                  NaN         4-2-3-1        4-2-3-1
# 6695                  NaN         3-4-1-2      4-1-2-1-2
# 6696                  NaN        4/4/2002        4-3-1-2
# 6697                  NaN         4-2-3-1        4-2-3-1
#
# [6698 rows x 206 columns]

# %%
matches_file_df.columns.all

# %%
pd.options.display.max_columns=None

# %%
matches_file_df

# %%
matches_file_df.drop(columns=['away_bench_14_num', 'away_bench_14', 'away_bench_14_minute', 'away_bench_13_minute', 'away_bench_13', 'away_bench_13_num', 'away_starting_22', 'away_starting_22_num', 'away_bench_12_num', 'away_bench_12_minute', 'away_bench_12', 'away_bench_11', 'away_bench_11_num', 'away_bench_11_minute',  ], inplace=True)

# %%
matches_file_df

# %%
selection = matches_file_df[['id','home','away', 'date', 'year', 'attendance', 'venue', 'league', 'part_of_competition',	'game_status', 'shootout', 'home_score', 'away_score', 'home_possessionPct', 'away_possessionPct', 'home_shotsSummary',	'away_shotsSummary', 'home_foulsCommitted', 'away_foulsCommitted', 'home_yellowCards', 'away_yellowCards', 'home_redCards', 'away_redCards', 'home_offsides', 'away_offsides', 'home_wonCorners', 'away_wonCorners', 'home_saves', 'away_saves', 'home_formation', 'away_formation']]
print(selection)
